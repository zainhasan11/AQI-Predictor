# %%
# !pip install openmeteo-requests requests-cache retry-requests pandas numpy lightgbm scikit-learn shap duckdb
# Out:
# Requirement already satisfied: openmeteo-requests in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.7.5)
# Requirement already satisfied: requests-cache in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.3.3)
# Requirement already satisfied: retry-requests in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (2.0.0)
# Requirement already satisfied: pandas in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (3.0.2)
# Requirement already satisfied: numpy in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (2.4.4)
# Requirement already satisfied: lightgbm in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (4.7.0)
# Requirement already satisfied: scikit-learn in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.8.0)
# Collecting shap
#   Downloading shap-0.51.0-cp311-cp311-win_amd64.whl.metadata (26 kB)
# Collecting duckdb
#   Downloading duckdb-1.5.5-cp311-cp311-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: niquests>=3.15.2 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from openmeteo-requests) (3.20.1)
# Requirement already satisfied: openmeteo-sdk>=1.22.0 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from openmeteo-requests) (1.27.2)
# Requirement already satisfied: attrs>=21.2 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests-cache) (26.1.0)
# Requirement already satisfied: cattrs>=22.2 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests-cache) (26.1.0)
# Requirement already satisfied: platformdirs>=2.5 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests-cache) (4.9.6)
# Requirement already satisfied: requests>=2.22 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests-cache) (2.33.1)
# Requirement already satisfied: url-normalize>=2.0 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests-cache) (3.0.0)
# Requirement already satisfied: urllib3>=1.25.5 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests-cache) (2.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas) (2026.1)
# Requirement already satisfied: narwhals>=1.15 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from lightgbm) (2.19.0)
# Requirement already satisfied: scipy in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from lightgbm) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tqdm>=4.27.0 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from shap) (4.68.3)
# Requirement already satisfied: packaging>20.9 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from shap) (26.1)
# Collecting slicer==0.0.8 (from shap)
#   Downloading slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Collecting numba (from shap)
#   Downloading numba-0.66.0-cp311-cp311-win_amd64.whl.metadata (2.6 kB)
# Collecting llvmlite (from shap)
#   Downloading llvmlite-0.48.0-cp311-cp311-win_amd64.whl.metadata (4.9 kB)
# Collecting cloudpickle (from shap)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from shap) (4.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from niquests>=3.15.2->openmeteo-requests) (3.4.7)
# Requirement already satisfied: urllib3-future<3,>=2.13.903 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from niquests>=3.15.2->openmeteo-requests) (2.23.900)
# Requirement already satisfied: wassima<3,>=1.0.1 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from niquests>=3.15.2->openmeteo-requests) (2.1.2)
# Requirement already satisfied: h11<1.0.0,>=0.11.0 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests) (0.16.0)
# Requirement already satisfied: jh2<6.0.0,>=5.0.3 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests) (5.0.13)
# Requirement already satisfied: qh3<2.0.0,>=1.5.4 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests) (1.9.4)
# Requirement already satisfied: flatbuffers==25.9.23 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from openmeteo-sdk>=1.22.0->openmeteo-requests) (25.9.23)
# Requirement already satisfied: six>=1.5 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.22->requests-cache) (3.11)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.22->requests-cache) (2026.2.25)
# Requirement already satisfied: colorama in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Downloading shap-0.51.0-cp311-cp311-win_amd64.whl (554 kB)
#    ---------------------------------------- 0.0/554.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/554.9 kB ? eta -:--:--
#    ---------------------------------------- 554.9/554.9 kB 1.9 MB/s  0:00:00
# Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Downloading duckdb-1.5.5-cp311-cp311-win_amd64.whl (13.2 MB)
#    ---------------------------------------- 0.0/13.2 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/13.2 MB 4.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.4/13.2 MB 6.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.5/13.2 MB 8.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.6/13.2 MB 8.4 MB/s eta 0:00:01
#    -------------------------- ------------- 8.7/13.2 MB 8.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.4/13.2 MB 7.0 MB/s eta 0:00:01
#    ------------------------------ --------- 10.0/13.2 MB 6.7 MB/s eta 0:00:01
#    ------------------------------- -------- 10.5/13.2 MB 6.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.8/13.2 MB 6.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.8/13.2 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.2 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 13.2/13.2 MB 5.3 MB/s  0:00:02
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading llvmlite-0.48.0-cp311-cp311-win_amd64.whl (41.9 MB)
#    ---------------------------------------- 0.0/41.9 MB ? eta -:--:--
#    - -------------------------------------- 1.6/41.9 MB 7.6 MB/s eta 0:00:06
#    -- ------------------------------------- 2.4/41.9 MB 7.4 MB/s eta 0:00:06
#    --- ------------------------------------ 3.1/41.9 MB 6.4 MB/s eta 0:00:07
#    --- ------------------------------------ 3.4/41.9 MB 4.2 MB/s eta 0:00:10
#    --- ------------------------------------ 3.7/41.9 MB 3.8 MB/s eta 0:00:11
#    ---- ----------------------------------- 4.5/41.9 MB 3.5 MB/s eta 0:00:11
#    ----- ---------------------------------- 5.5/41.9 MB 3.6 MB/s eta 0:00:11
#    ----- ---------------------------------- 6.0/41.9 MB 3.5 MB/s eta 0:00:11
#    ------ --------------------------------- 7.1/41.9 MB 3.7 MB/s eta 0:00:10
#    ------- -------------------------------- 7.3/41.9 MB 3.5 MB/s eta 0:00:10
#    ------- -------------------------------- 7.6/41.9 MB 3.2 MB/s eta 0:00:11
#    -------- ------------------------------- 8.4/41.9 MB 3.3 MB/s eta 0:00:11
#    -------- ------------------------------- 8.9/41.9 MB 3.3 MB/s eta 0:00:10
#    --------- ------------------------------ 9.7/41.9 MB 3.2 MB/s eta 0:00:11
#    ---------- ----------------------------- 10.5/41.9 MB 3.2 MB/s eta 0:00:10
#    ----------- ---------------------------- 11.8/41.9 MB 3.4 MB/s eta 0:00:09
#    ----------- ---------------------------- 12.1/41.9 MB 3.4 MB/s eta 0:00:09
#    ------------ --------------------------- 12.8/41.9 MB 3.3 MB/s eta 0:00:09
#    ------------ --------------------------- 13.4/41.9 MB 3.3 MB/s eta 0:00:09
#    ------------- -------------------------- 14.4/41.9 MB 3.4 MB/s eta 0:00:09
#    -------------- ------------------------- 15.5/41.9 MB 3.4 MB/s eta 0:00:08
#    --------------- ------------------------ 16.3/41.9 MB 3.4 MB/s eta 0:00:08
#    ---------------- ----------------------- 16.8/41.9 MB 3.4 MB/s eta 0:00:08
#    ---------------- ----------------------- 17.3/41.9 MB 3.4 MB/s eta 0:00:08
#    ----------------- ---------------------- 18.1/41.9 MB 3.4 MB/s eta 0:00:08
#    ------------------ --------------------- 19.1/41.9 MB 3.4 MB/s eta 0:00:07
#    ------------------- -------------------- 19.9/41.9 MB 3.5 MB/s eta 0:00:07
#    ------------------- -------------------- 20.4/41.9 MB 3.5 MB/s eta 0:00:07
#    -------------------- ------------------- 21.5/41.9 MB 3.4 MB/s eta 0:00:06
#    --------------------- ------------------ 22.0/41.9 MB 3.5 MB/s eta 0:00:06
#    --------------------- ------------------ 22.8/41.9 MB 3.5 MB/s eta 0:00:06
#    ---------------------- ----------------- 23.6/41.9 MB 3.5 MB/s eta 0:00:06
#    ----------------------- ---------------- 24.6/41.9 MB 3.5 MB/s eta 0:00:05
#    ------------------------ --------------- 25.4/41.9 MB 3.5 MB/s eta 0:00:05
#    ------------------------ --------------- 26.0/41.9 MB 3.5 MB/s eta 0:00:05
#    ------------------------- -------------- 26.7/41.9 MB 3.5 MB/s eta 0:00:05
#    ------------------------- -------------- 27.0/41.9 MB 3.4 MB/s eta 0:00:05
#    -------------------------- ------------- 27.5/41.9 MB 3.4 MB/s eta 0:00:05
#    -------------------------- ------------- 28.0/41.9 MB 3.4 MB/s eta 0:00:05
#    --------------------------- ------------ 28.6/41.9 MB 3.4 MB/s eta 0:00:04
#    ---------------------------- ----------- 29.4/41.9 MB 3.3 MB/s eta 0:00:04
#    ---------------------------- ----------- 29.9/41.9 MB 3.3 MB/s eta 0:00:04
#    ----------------------------- ---------- 30.7/41.9 MB 3.3 MB/s eta 0:00:04
#    ----------------------------- ---------- 31.2/41.9 MB 3.3 MB/s eta 0:00:04
#    ------------------------------ --------- 31.7/41.9 MB 3.3 MB/s eta 0:00:04
#    ------------------------------ --------- 32.2/41.9 MB 3.3 MB/s eta 0:00:03
#    ------------------------------- -------- 32.8/41.9 MB 3.3 MB/s eta 0:00:03
#    ------------------------------- -------- 33.3/41.9 MB 3.2 MB/s eta 0:00:03
#    -------------------------------- ------- 33.8/41.9 MB 3.2 MB/s eta 0:00:03
#    -------------------------------- ------- 34.3/41.9 MB 3.2 MB/s eta 0:00:03
#    --------------------------------- ------ 34.9/41.9 MB 3.2 MB/s eta 0:00:03
#    --------------------------------- ------ 35.4/41.9 MB 3.2 MB/s eta 0:00:03
#    ---------------------------------- ----- 36.2/41.9 MB 3.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 36.4/41.9 MB 3.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 37.0/41.9 MB 3.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 37.5/41.9 MB 3.1 MB/s eta 0:00:02
#    ------------------------------------ --- 38.0/41.9 MB 3.1 MB/s eta 0:00:02
#    ------------------------------------ --- 38.5/41.9 MB 3.1 MB/s eta 0:00:02
#    ------------------------------------- -- 39.1/41.9 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------- -- 39.6/41.9 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 40.1/41.9 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 40.6/41.9 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.9 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  41.4/41.9 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  41.7/41.9 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 41.9/41.9 MB 3.0 MB/s  0:00:14
# Downloading numba-0.66.0-cp311-cp311-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.8 MB 2.1 MB/s eta 0:00:02
#    --------------- ------------------------ 1.0/2.8 MB 2.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.6/2.8 MB 2.4 MB/s eta 0:00:01
#    ------------------------------ --------- 2.1/2.8 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 2.6 MB/s  0:00:01
# Installing collected packages: slicer, llvmlite, duckdb, cloudpickle, numba, shap
#
#    ---------------------------------------- 0/6 [slicer]
#    ------ --------------------------------- 1/6 [llvmlite]
#    ------ --------------------------------- 1/6 [llvmlite]
#    ------ --------------------------------- 1/6 [llvmlite]
#    ------ --------------------------------- 1/6 [llvmlite]
#    ------ --------------------------------- 1/6 [llvmlite]
#    ------ --------------------------------- 1/6 [llvmlite]
#    ------ --------------------------------- 1/6 [llvmlite]
#    ------ --------------------------------- 1/6 [llvmlite]
#    ------ --------------------------------- 1/6 [llvmlite]
#    ------ --------------------------------- 1/6 [llvmlite]
#    ------ --------------------------------- 1/6 [llvmlite]
#    ------ --------------------------------- 1/6 [llvmlite]
#    ------ --------------------------------- 1/6 [llvmlite]
#    ------ --------------------------------- 1/6 [llvmlite]
#    ------ --------------------------------- 1/6 [llvmlite]
#    ------ --------------------------------- 1/6 [llvmlite]
#    ------ --------------------------------- 1/6 [llvmlite]
#    ------------- -------------------------- 2/6 [duckdb]
#    ------------- -------------------------- 2/6 [duckdb]
#    ------------- -------------------------- 2/6 [duckdb]
#    ------------- -------------------------- 2/6 [duckdb]
#    ------------- -------------------------- 2/6 [duckdb]
#    ------------- -------------------------- 2/6 [duckdb]
#    ------------- -------------------------- 2/6 [duckdb]
#    ------------- -------------------------- 2/6 [duckdb]
#    ------------- -------------------------- 2/6 [duckdb]
#    ------------- -------------------------- 2/6 [duckdb]
#    ------------- -------------------------- 2/6 [duckdb]
#    ------------- -------------------------- 2/6 [duckdb]
#    -------------------- ------------------- 3/6 [cloudpickle]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    --------------------------------- ------ 5/6 [shap]
#    --------------------------------- ------ 5/6 [shap]
#    --------------------------------- ------ 5/6 [shap]
#    --------------------------------- ------ 5/6 [shap]
#    --------------------------------- ------ 5/6 [shap]
#    --------------------------------- ------ 5/6 [shap]
#    --------------------------------- ------ 5/6 [shap]
#    --------------------------------- ------ 5/6 [shap]
#    --------------------------------- ------ 5/6 [shap]
#    --------------------------------- ------ 5/6 [shap]
#    --------------------------------- ------ 5/6 [shap]
#    --------------------------------- ------ 5/6 [shap]
#    --------------------------------- ------ 5/6 [shap]
#    --------------------------------- ------ 5/6 [shap]
#    --------------------------------- ------ 5/6 [shap]
#    --------------------------------- ------ 5/6 [shap]
#    --------------------------------- ------ 5/6 [shap]
#    --------------------------------- ------ 5/6 [shap]
#    --------------------------------- ------ 5/6 [shap]
#    --------------------------------- ------ 5/6 [shap]
#    --------------------------------- ------ 5/6 [shap]
#    --------------------------------- ------ 5/6 [shap]
#    ---------------------------------------- 6/6 [shap]
#
# Successfully installed cloudpickle-3.1.2 duckdb-1.5.5 llvmlite-0.48.0 numba-0.66.0 shap-0.51.0 slicer-0.0.8
# WARNING: Ignoring invalid distribution ~ip (C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages)

# %%
import openmeteo_requests
import requests_cache
from retry_requests import retry
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# 1. Setup Open-Meteo Client
cache_session = requests_cache.CachedSession('.cache', expire_after=3600)
retry_session = retry(cache_session, retries=5, backoff_factor=0.2)
openmeteo = openmeteo_requests.Client(session=retry_session)

LATITUDE = 33.6844
LONGITUDE = 73.0479

# Fetch past 1 year (365 days) of historical air quality data
today = datetime.now().date()
start_date = (today - timedelta(days=365)).strftime('%Y-%m-%d')
end_date = today.strftime('%Y-%m-%d')

print(f"Fetching historical backfill data from {start_date} to {end_date}...")

aq_url = "https://air-quality-api.open-meteo.com/v1/air-quality"
aq_params = {
    "latitude": LATITUDE,
    "longitude": LONGITUDE,
    "start_date": start_date,
    "end_date": end_date,
    "hourly": ["pm10", "pm2_5", "carbon_monoxide", "nitrogen_dioxide", "sulphur_dioxide", "ozone", "us_aqi"]
}

aq_response = openmeteo.weather_api(aq_url, params=aq_params)[0]
aq_hourly = aq_response.Hourly()

time_stamps = pd.date_range(
    start=pd.to_datetime(aq_hourly.Time(), unit="s", utc=True),
    end=pd.to_datetime(aq_hourly.TimeEnd(), unit="s", utc=True),
    freq=pd.Timedelta(seconds=aq_hourly.Interval()),
    inclusive="left"
)

df_aq = pd.DataFrame({
    "date_time": time_stamps,
    "pm10": aq_hourly.Variables(0).ValuesAsNumpy(),
    "pm2_5": aq_hourly.Variables(1).ValuesAsNumpy(),
    "co": aq_hourly.Variables(2).ValuesAsNumpy(),
    "no2": aq_hourly.Variables(3).ValuesAsNumpy(),
    "so2": aq_hourly.Variables(4).ValuesAsNumpy(),
    "ozone": aq_hourly.Variables(5).ValuesAsNumpy(),
    "us_aqi": aq_hourly.Variables(6).ValuesAsNumpy()
})

print(f"Total historical rows fetched: {len(df_aq)}")

# 2. Feature Engineering
df_features = df_aq.copy().sort_values("date_time").reset_index(drop=True)

df_features["hour"] = df_features["date_time"].dt.hour
df_features["day_of_week"] = df_features["date_time"].dt.dayofweek
df_features["month"] = df_features["date_time"].dt.month

df_features["aqi_lag_1h"] = df_features["us_aqi"].shift(1)
df_features["aqi_lag_3h"] = df_features["us_aqi"].shift(3)
df_features["aqi_lag_24h"] = df_features["us_aqi"].shift(24)
df_features["aqi_change_rate"] = df_features["us_aqi"] - df_features["aqi_lag_1h"]

# Target: AQI 24 hours into the future
df_features["target_aqi_24h"] = df_features["us_aqi"].shift(-24)

df_clean = df_features.dropna().reset_index(drop=True)
print(f"Clean features ready for training: {len(df_clean)} rows.")

# 3. Store in DuckDB Feature Store
import duckdb
conn = duckdb.connect('feature_store.duckdb')
conn.execute("CREATE OR REPLACE TABLE aqi_features AS SELECT * FROM df_clean")
conn.close()
print("Updated Feature Store with 1 year of historical data!")
# Out:
# Fetching historical backfill data from 2025-07-22 to 2026-07-22...
# Total historical rows fetched: 8784
# Clean features ready for training: 8736 rows.
# Updated Feature Store with 1 year of historical data!

# %%
df_features = df_aq.copy().sort_values("date_time").reset_index(drop=True)

# 1. Temporal Features
df_features["hour"] = df_features["date_time"].dt.hour
df_features["day_of_week"] = df_features["date_time"].dt.dayofweek
df_features["month"] = df_features["date_time"].dt.month

# 2. Lag Features (AQI dynamics)
df_features["aqi_lag_1h"] = df_features["us_aqi"].shift(1)
df_features["aqi_lag_3h"] = df_features["us_aqi"].shift(3)
df_features["aqi_change_rate"] = df_features["us_aqi"] - df_features["aqi_lag_1h"]

# 3. Target (AQI 24 hours into the future)
df_features["target_aqi_24h"] = df_features["us_aqi"].shift(-24)

# Clean nulls
df_clean = df_features.dropna().reset_index(drop=True)

print("Processed Feature Set Preview:")
df_clean[['date_time', 'us_aqi', 'aqi_change_rate', 'target_aqi_24h']].head()
# Out:
# Processed Feature Set Preview:
#                   date_time     us_aqi  aqi_change_rate  target_aqi_24h
# 0 2025-07-22 03:00:00+00:00  86.438683        -1.973259       83.034584
# 1 2025-07-22 04:00:00+00:00  84.858482        -1.580200       82.704399
# 2 2025-07-22 05:00:00+00:00  83.867920        -0.990562       82.413521
# 3 2025-07-22 06:00:00+00:00  83.136787        -0.731133       81.792450
# 4 2025-07-22 07:00:00+00:00  82.036163        -1.100624       80.731133

# %%
import duckdb

# Connect to a local serverless Feature Store
conn = duckdb.connect('feature_store.duckdb')

# Register and store feature table
conn.execute("CREATE TABLE IF NOT EXISTS aqi_features AS SELECT * FROM df_clean")
print("Successfully written to DuckDB Feature Store!")

# Verify retrieval from Feature Store
stored_df = conn.execute("SELECT * FROM aqi_features").df()
conn.close()

print(f"Retrieved {len(stored_df)} feature rows from DuckDB.")
# Out:
# Successfully written to DuckDB Feature Store!
# Retrieved 8736 feature rows from DuckDB.

# %%
import duckdb
import pandas as pd
import numpy as np
import joblib
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.linear_model import Ridge
import lightgbm as lgb
import shap

# 1. Fetch training data from the DuckDB Feature Store
conn = duckdb.connect('feature_store.duckdb')
df = conn.execute("SELECT * FROM aqi_features").df()
conn.close()

# 2. Separate Features (X) and Target (y)
feature_cols = [
    'pm10', 'pm2_5', 'co', 'no2', 'so2', 'ozone', 'us_aqi',
    'hour', 'day_of_week', 'month', 'aqi_lag_1h', 'aqi_lag_3h', 'aqi_change_rate'
]
X = df[feature_cols]
y = df['target_aqi_24h']

# Split into 80% Train, 20% Test (chronological split is best for time-series)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# 3. Train Baseline Model (Ridge Regression)
ridge_model = Ridge()
ridge_model.fit(X_train, y_train)
y_pred_ridge = ridge_model.predict(X_test)

# 4. Train Main Model (LightGBM)
lgb_model = lgb.LGBMRegressor(n_estimators=100, learning_rate=0.05, random_state=42)
lgb_model.fit(X_train, y_train)
y_pred_lgb = lgb_model.predict(X_test)

# 5. Evaluate Metrics
def evaluate_model(y_true, y_pred, name):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"--- {name} Performance ---")
    print(f"RMSE: {rmse:.2f}")
    print(f"MAE:  {mae:.2f}")
    print(f"R²:   {r2:.4f}\n")
    return {"rmse": rmse, "mae": mae, "r2": r2}

metrics_ridge = evaluate_model(y_test, y_pred_ridge, "Ridge Regression")
metrics_lgb = evaluate_model(y_test, y_pred_lgb, "LightGBM Regressor")

import joblib
import os
import shap
import matplotlib.pyplot as plt

# 1. Save Ridge as our primary production model
os.makedirs("model_registry", exist_ok=True)
joblib.dump(ridge_model, "model_registry/aqi_model.pkl")
print("Saved top-performing Ridge Regression model to 'model_registry/aqi_model.pkl'!")

# 2. Compute SHAP values for Ridge Explanations
explainer = shap.LinearExplainer(ridge_model, X_train)
shap_values = explainer(X_test)

# Plot feature importance summary
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X_test, show=False)
plt.title("Feature Importance Driving 24-Hour AQI Predictions", fontsize=14)
plt.tight_layout()
plt.savefig("model_registry/shap_summary.png")
plt.show()
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000782 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2557
# [LightGBM] [Info] Number of data points in the train set: 6988, number of used features: 13
# [LightGBM] [Info] Start training from score 113.526450
# --- Ridge Regression Performance ---
# RMSE: 17.62
# MAE:  13.44
# R²:   0.7136
#
# --- LightGBM Regressor Performance ---
# RMSE: 19.03
# MAE:  14.66
# R²:   0.6658
#
# Saved top-performing Ridge Regression model to 'model_registry/aqi_model.pkl'!

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import numpy as np
import joblib
import openmeteo_requests
import requests_cache
from retry_requests import retry
import plotly.graph_objects as go
import os

# Page Configuration
st.set_page_config(
    page_title="Pearls AQI Predictor",
    page_icon="🌫️",
    layout="wide"
)

# Title & Description
st.title("🌫️ Pearls Air Quality Index (AQI) Predictor")
st.markdown("Real-time air quality monitoring and **24-hour forecasting** powered by serverless ML.")

# 1. Load Model
@st.cache_resource
def load_model():
    model_path = "model_registry/aqi_model.pkl"
    if os.path.exists(model_path):
        return joblib.load(model_path)
    return None

model = load_model()

# 2. Fetch Live Data Function
@st.cache_data(ttl=1800)  # Refresh every 30 mins
def fetch_live_aqi():
    cache_session = requests_cache.CachedSession('.cache', expire_after=1800)
    retry_session = retry(cache_session, retries=5, backoff_factor=0.2)
    openmeteo = openmeteo_requests.Client(session=retry_session)

    LATITUDE = 33.6844   # Islamabad
    LONGITUDE = 73.0479

    aq_url = "https://air-quality-api.open-meteo.com/v1/air-quality"
    aq_params = {
        "latitude": LATITUDE,
        "longitude": LONGITUDE,
        "hourly": ["pm10", "pm2_5", "carbon_monoxide", "nitrogen_dioxide", "sulphur_dioxide", "ozone", "us_aqi"],
        "forecast_days": 3
    }

    aq_response = openmeteo.weather_api(aq_url, params=aq_params)[0]
    aq_hourly = aq_response.Hourly()

    time_stamps = pd.date_range(
        start=pd.to_datetime(aq_hourly.Time(), unit="s", utc=True),
        end=pd.to_datetime(aq_hourly.TimeEnd(), unit="s", utc=True),
        freq=pd.Timedelta(seconds=aq_hourly.Interval()),
        inclusive="left"
    )

    df_aq = pd.DataFrame({
        "date_time": time_stamps,
        "pm10": aq_hourly.Variables(0).ValuesAsNumpy(),
        "pm2_5": aq_hourly.Variables(1).ValuesAsNumpy(),
        "co": aq_hourly.Variables(2).ValuesAsNumpy(),
        "no2": aq_hourly.Variables(3).ValuesAsNumpy(),
        "so2": aq_hourly.Variables(4).ValuesAsNumpy(),
        "ozone": aq_hourly.Variables(5).ValuesAsNumpy(),
        "us_aqi": aq_hourly.Variables(6).ValuesAsNumpy()
    })
    return df_aq

# Helper for AQI Category & Colors
def get_aqi_status(aqi):
    if aqi <= 50:
        return "Good", "🟢", "#00e400"
    elif aqi <= 100:
        return "Moderate", "🟡", "#ffff00"
    elif aqi <= 150:
        return "Unhealthy for Sensitive Groups", "🟠", "#ff7e00"
    elif aqi <= 200:
        return "Unhealthy", "🔴", "#ff0000"
    elif aqi <= 300:
        return "Very Unhealthy", "🟣", "#8f3f97"
    else:
        return "Hazardous", "🤎", "#7e0023"

# Main Logic
try:
    df_live = fetch_live_aqi()
    current_row = df_live.iloc[0]
    current_aqi = int(current_row['us_aqi'])
    status, emoji, color = get_aqi_status(current_aqi)

    # Top Metrics Bar
    col1, col2, col3, col4 = st.columns(4)
    with col1:
        st.metric(label="Current US AQI", value=f"{current_aqi} {emoji}")
    with col2:
        st.metric(label="AQI Category", value=status)
    with col3:
        st.metric(label="PM2.5", value=f"{current_row['pm2_5']:.1f} µg/m³")
    with col4:
        st.metric(label="PM10", value=f"{current_row['pm10']:.1f} µg/m³")

    st.divider()

    # Predict Future AQI
    if model is not None:
        # Prepare feature vector for prediction matching exact training columns
        df_feat = df_live.copy()
        df_feat["hour"] = df_feat["date_time"].dt.hour
        df_feat["day_of_week"] = df_feat["date_time"].dt.dayofweek
        df_feat["month"] = df_feat["date_time"].dt.month
        df_feat["aqi_lag_1h"] = df_feat["us_aqi"].shift(1).fillna(current_aqi)
        df_feat["aqi_lag_3h"] = df_feat["us_aqi"].shift(3).fillna(current_aqi)
        df_feat["aqi_change_rate"] = df_feat["us_aqi"] - df_feat["aqi_lag_1h"]

        feature_cols = [
            'pm10', 'pm2_5', 'co', 'no2', 'so2', 'ozone', 'us_aqi',
            'hour', 'day_of_week', 'month', 'aqi_lag_1h', 'aqi_lag_3h', 'aqi_change_rate'
        ]

        predicted_aqi = int(model.predict(df_feat[feature_cols].iloc[[0]])[0])
        pred_status, pred_emoji, _ = get_aqi_status(predicted_aqi)

        st.subheader("🤖 Model Forecast (Next 24 Hours)")
        st.info(f"Forecasted AQI for tomorrow: **{predicted_aqi} ({pred_status} {pred_emoji})**")

        # Alert Banner for High AQI
        if predicted_aqi > 150:
            st.error(f"🚨 **HAZARDOUS AIR QUALITY ALERT:** The forecasted AQI is **{predicted_aqi}**. Sensitive individuals and outdoor activities should be limited!")

    # Interactive Trend Plot
    st.subheader("📈 3-Day Air Quality Trend")
    fig = go.Figure()
    fig.add_trace(go.Scatter(
        x=df_live['date_time'], 
        y=df_live['us_aqi'],
        mode='lines+markers',
        name='Hourly AQI',
        line=dict(color='#1f77b4', width=3)
    ))
    fig.update_layout(
        xaxis_title="Time",
        yaxis_title="US AQI Index",
        hovermode="x unified",
        margin=dict(l=20, r=20, t=30, b=20)
    )
    st.plotly_chart(fig, use_container_width=True)

    # Feature Importance Section
    if os.path.exists("model_registry/shap_summary.png"):
        st.divider()
        st.subheader("💡 Model Explainability (SHAP Importance)")
        st.image("model_registry/shap_summary.png", caption="Key features influencing AQI predictions", use_column_width=True)

except Exception as e:
    st.error(f"Error loading dashboard data: {e}")
# Out:
# Overwriting app.py

# %%
# !pip install streamlit plotly
# Out:
# Requirement already satisfied: streamlit in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.56.0)
# Requirement already satisfied: plotly in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (6.9.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (7.0.5)
# Requirement already satisfied: click<9,>=7.0 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (8.4.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (3.1.46)
# Requirement already satisfied: numpy<3,>=1.23 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (2.4.4)
# Requirement already satisfied: packaging>=20 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (26.1)
# Requirement already satisfied: pandas<4,>=1.4.0 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (3.0.2)
# Requirement already satisfied: pillow<13,>=7.1.0 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (12.2.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (0.9.2)
# Requirement already satisfied: protobuf<8,>=3.20 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (7.34.1)
# Requirement already satisfied: pyarrow>=7.0 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (23.0.1)
# Requirement already satisfied: requests<3,>=2.27 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (2.33.1)
# Requirement already satisfied: tenacity<10,>=8.1.0 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (6.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.27.1 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.19.0)
# Requirement already satisfied: colorama in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3,>=2.27->streamlit) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3,>=2.27->streamlit) (2026.2.25)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\zainh\AppData\Local\Programs\Python\Python311\Lib\site-packages)
